# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ##Variable Details
#
# ####Rules
#
# - Variable is a container that hold values
# - Naming of the variables are very important
# - You can not name a variable with a reserved keyword
# - The variable name can not begin with a number , special character like .
# - It must start with either text or _

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Wrong variable names
False = 10
print(False)
# Out:
#   File "/tmp/ipython-input-1137889788.py", line 2
#     False = 10
#     ^
# SyntaxError: cannot assign to False

# %%
.jp = 15
print(29jp)
# Out:
#   File "/tmp/ipython-input-2239633130.py", line 2
#     print(29jp)
#             ^
# SyntaxError: invalid imaginary literal

# %%
#right ways to name a variable
ab = 10
cd = 20
_ef = 30
print(_ef)
# Out:
# 30

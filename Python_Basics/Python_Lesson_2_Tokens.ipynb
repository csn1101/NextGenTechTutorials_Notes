# %% [markdown]
# ### Tokens
#
# tokens are smallest units of a program
#
# 1. Keywords
# 2. Identifiers
# 3. Literals
# 4. Punctuators

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#variable assignments
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
#multiple variable assignments
a,b,c = 10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
#punctuators
# : , {} , () , []

# %% [markdown]
# ### Literals
#
# 1. String Literals
# 2. Numeric Literals
# 3. Float Literals
# 4. Special Literals

# %%
a = "hello world"
print(a)
print(type(a))
# Out:
# hello world
# <class 'str'>

# %%
a = 25
print(a)
print(type(a))
# Out:
# 25
# <class 'int'>

# %%
a = 25.6
print(a)
print(type(a))
# Out:
# 25.6
# <class 'float'>

# %%
c = None
print(type(c))
# Out:
# <class 'NoneType'>

# %%
c = True
print(type(c))
# Out:
# <class 'bool'>

# %%
#Static Typing vs Dynamic Typing
# Static Typing requires you to provide fixed data type
# to the variable before assignment
# c = string ("hello")
#dynamic typing
c = "hello"
print(type(c))
# Out:
# <class 'str'>

# %%
c = 25
print(type(c))
# Out:
# <class 'int'>
